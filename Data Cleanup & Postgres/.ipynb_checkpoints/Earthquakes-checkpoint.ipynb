# %% [markdown]
# ## Libraries

# %% [markdown]
# ### Note: You need to install below library in order for code to work
# ### pip install reverse_geocoder

# %%
# Import Pandas and NumPy
import pandas as pd
import numpy as np
import datetime as dt

# Import SQL Alchemy
from sqlalchemy import create_engine
import psycopg2

# Import Password
from config import password

# Import Reverse Geocoder library which takes a latitude / longitude coordinate and returns the nearest town/city
import reverse_geocoder as rg

# %%
# Earthquakes
# Save path to data set in a variable
Earthquakes = "../Resources/Earthquakes.csv"

# Use Pandas to read data
Earthquakes_df = pd.read_csv(Earthquakes)
Earthquakes_df.head()
# Out:
#                        time   latitude   longitude      depth   mag magType  \
# 0  2021-04-17T22:20:57.320Z  32.751000 -115.829333   6.040000  1.24      ml
# 1  2021-04-17T22:18:44.955Z  60.299400 -141.245600   3.000000  1.50      ml
# 2  2021-04-17T22:13:31.910Z  19.182333 -155.393997  34.349998  1.85      md
# 3  2021-04-17T22:07:23.157Z  69.062500 -146.475500   1.200000  3.00      ml
# 4  2021-04-17T22:05:27.560Z  32.400833 -115.487333   1.010000  1.77      ml
#
#     nst    gap    dmin   rms  ...                   updated  \
# 0  17.0   72.0  0.1296  0.22  ...  2021-04-17T22:24:25.471Z
# 1   NaN    NaN     NaN  0.59  ...  2021-04-17T22:22:37.941Z
# 2  38.0  166.0     NaN  0.12  ...  2021-04-17T22:16:49.020Z
# 3   NaN    NaN     NaN  0.78  ...  2021-04-17T22:20:57.579Z
# 4  15.0  120.0  0.1553  0.28  ...  2021-04-17T22:09:47.387Z
#
#                                   place        type horizontalError  \
# 0                15km E of Ocotillo, CA  earthquake            0.62
# 1          119 km NW of Yakutat, Alaska  earthquake             NaN
# 2            9 km ESE of Pāhala, Hawaii  earthquake            0.69
# 3  111 km NNW of Arctic Village, Alaska  earthquake             NaN
# 4        22km SSE of Progreso, B.C., MX  earthquake            0.66
#
#   depthError  magError  magNst     status  locationSource magSource
# 0       2.82     0.224    16.0  automatic              ci        ci
# 1       0.20       NaN     NaN  automatic              ak        ak
# 2       0.83     0.880     7.0  automatic              hv        hv
# 3       0.60       NaN     NaN  automatic              ak        ak
# 4      31.61     0.258    22.0  automatic              ci        ci
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# get list of all columns
Earthquakes_df.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
# check all columns with any missing/null values
Earthquakes_df.isna().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   3
# magType               3
# nst                2486
# gap                1527
# dmin               3216
# rms                   0
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2871
# depthError            0
# magError           2123
# magNst             1798
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
# drop the unwanted columns
Earthquakes_df.drop(columns = ['horizontalError', 'depthError', 'magError','nst', 'gap', 'dmin', 'magNst', 'net'], inplace=True)

# %%
# Count no of records
Earthquakes_df['id'].count()
# Out:
# 10328

# %%
# Drop any missing/null values
Earthquakes_df.dropna(inplace=True)

# %%
# Re-count no of records after drop
Earthquakes_df['id'].count()
# Out:
# 10325

# %%
# Format the Time field to get the date in %Y-%m-%d %H:%M:%S format
Earthquakes_df['time'] = pd.to_datetime(Earthquakes_df['time'], format='%Y-%m-%d %H:%M:%S', errors='ignore').dt.tz_convert(None)
Earthquakes_df['time'] = Earthquakes_df['time'].dt.ceil(freq='s')

# %%
# Format the updated field to get the date in %Y-%m-%d %H:%M:%S format
Earthquakes_df['updated'] = pd.to_datetime(Earthquakes_df['updated'], format='%Y-%m-%d %H:%M:%S', errors='ignore').dt.tz_convert(None)
Earthquakes_df['updated'] = Earthquakes_df['updated'].dt.ceil(freq='s')

# %%
# Convert both lat and long columns into tuples
subset = Earthquakes_df[['latitude', 'longitude']]
tuples = [tuple(x) for x in subset.values]
#print(tuples)

# %%
# sample test
coordinates = (32.751, -115.8293333), (60.2994,-141.2456)
rg.search(coordinates)
# Out:
# [{'lat': '32.79311',
#   'lon': '-115.69111',
#   'name': 'Seeley',
#   'admin1': 'California',
#   'admin2': 'Imperial County',
#   'cc': 'US'},
#  {'lat': '63.33667',
#   'lon': '-142.98556',
#   'name': 'Tok',
#   'admin1': 'Alaska',
#   'admin2': 'Southeast Fairbanks Census Area',
#   'cc': 'US'}]

# %%
# coordinates = (32.751, -115.8293333), (60.2994,-141.2456)
# Pass the tuples as an input to reverse_geocoder to get City, County, State and Country
geocode_df = pd.DataFrame(rg.search(tuples))
geocode_df.head()
# Out:
#         lat         lon         name           admin1  \
# 0  32.79311  -115.69111       Seeley       California
# 1  63.33667  -142.98556          Tok           Alaska
# 2   19.2025  -155.47694       Pahala           Hawaii
# 3  70.25528  -148.33722  Prudhoe Bay           Alaska
# 4  32.58039  -115.58479     Progreso  Baja California
#
#                             admin2  cc
# 0                  Imperial County  US
# 1  Southeast Fairbanks Census Area  US
# 2                    Hawaii County  US
# 3              North Slope Borough  US
# 4                                   MX

# %%
# Rename the columns
geocode_df.rename(columns = {"lat" : "latitude", "lon" : "longitude", "name" : "City", "admin1" : "State", "admin2" : "County", "cc" : "Country"}, inplace=True)
geocode_df.head()
# Out:
#    latitude   longitude         City            State  \
# 0  32.79311  -115.69111       Seeley       California
# 1  63.33667  -142.98556          Tok           Alaska
# 2   19.2025  -155.47694       Pahala           Hawaii
# 3  70.25528  -148.33722  Prudhoe Bay           Alaska
# 4  32.58039  -115.58479     Progreso  Baja California
#
#                             County Country
# 0                  Imperial County      US
# 1  Southeast Fairbanks Census Area      US
# 2                    Hawaii County      US
# 3              North Slope Borough      US
# 4                                       MX

# %%
# verify the counts
Earthquakes_df['id'].count()
# Out:
# 10325

# %%
# verify the counts
geocode_df['latitude'].count()
# Out:
# 10325

# %%
# Merge both df's based on Index to get City, State, County and Country into Earthquakes_df
# Note: We could have merged based on Lat and Long but their float values are slighly off which retruns nothing after merge
merge_df = Earthquakes_df.merge(geocode_df, left_index=True, right_index=True)

# %%
# drop the unwanted columns
merge_df.drop(columns = ['latitude_y', 'longitude_y', 'magSource'], inplace=True)

# %%
# Rename the columns
merge_df.rename(columns = {"latitude_x" : "latitude", "longitude_x" : "longitude", "rms" : "rootMeanSquare", 'updated': 'lastUpdDatetime'}, inplace=True)
merge_df.head()
# Out:
#                  time   latitude   longitude      depth   mag magType  \
# 0 2021-04-17 22:20:58  32.751000 -115.829333   6.040000  1.24      ml
# 1 2021-04-17 22:18:45  60.299400 -141.245600   3.000000  1.50      ml
# 2 2021-04-17 22:13:32  19.182333 -155.393997  34.349998  1.85      md
# 3 2021-04-17 22:07:24  69.062500 -146.475500   1.200000  3.00      ml
# 4 2021-04-17 22:05:28  32.400833 -115.487333   1.010000  1.77      ml
#
#    rootMeanSquare            id     lastUpdDatetime  \
# 0            0.22    ci39854328 2021-04-17 22:24:26
# 1            0.59  ak0214xbpmk2 2021-04-17 22:22:38
# 2            0.12    hv72430407 2021-04-17 22:16:50
# 3            0.78  ak0214xbn842 2021-04-17 22:20:58
# 4            0.28    ci39854320 2021-04-17 22:09:48
#
#                                   place        type     status locationSource  \
# 0                15km E of Ocotillo, CA  earthquake  automatic             ci
# 1          119 km NW of Yakutat, Alaska  earthquake  automatic             ak
# 2            9 km ESE of Pāhala, Hawaii  earthquake  automatic             hv
# 3  111 km NNW of Arctic Village, Alaska  earthquake  automatic             ak
# 4        22km SSE of Progreso, B.C., MX  earthquake  automatic             ci
#
#           City            State                           County Country
# 0       Seeley       California                  Imperial County      US
# 1          Tok           Alaska  Southeast Fairbanks Census Area      US
# 2       Pahala           Hawaii                    Hawaii County      US
# 3  Prudhoe Bay           Alaska              North Slope Borough      US
# 4     Progreso  Baja California                                       MX

# %%
# Replace white spaces in newly added fields with NaN
merge_df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
# check all columns with any missing/null values
merge_df.isna().sum()
# Out:
# time                 0
# latitude             0
# longitude            0
# depth                0
# mag                  0
# magType              0
# rootMeanSquare       0
# id                   0
# lastUpdDatetime      0
# place                0
# type                 0
# status               0
# locationSource       0
# City                 0
# State               27
# County             973
# Country              0
# dtype: int64

# %%
# Drop any missing/null values
merge_df.dropna(inplace=True)

# %%
# verify the counts
merge_df['id'].count()
# Out:
# 9349

# %%
# Earthquake Df
Earthquake = pd.DataFrame(merge_df, columns = ['id', 'type', 'depth','mag', 'magType', 'rootMeanSquare', 'status'])
Earthquake.head()
# Out:
#              id        type       depth   mag magType  rootMeanSquare  \
# 0    ci39854328  earthquake    6.040000  1.24      ml            0.22
# 1  ak0214xbpmk2  earthquake    3.000000  1.50      ml            0.59
# 2    hv72430407  earthquake   34.349998  1.85      md            0.12
# 3  ak0214xbn842  earthquake    1.200000  3.00      ml            0.78
# 5  ak0214xbmcgy  earthquake  124.800000  1.30      ml            0.43
#
#       status
# 0  automatic
# 1  automatic
# 2  automatic
# 3  automatic
# 5  automatic

# %%
# Location Df
Location = pd.DataFrame(merge_df, columns = ['id', 'place', 'latitude','longitude', 'locationSource', 'City', 'County', 'State', 'Country'])
Location.head()
# Out:
#              id                                 place   latitude   longitude  \
# 0    ci39854328                15km E of Ocotillo, CA  32.751000 -115.829333
# 1  ak0214xbpmk2          119 km NW of Yakutat, Alaska  60.299400 -141.245600
# 2    hv72430407            9 km ESE of Pāhala, Hawaii  19.182333 -155.393997
# 3  ak0214xbn842  111 km NNW of Arctic Village, Alaska  69.062500 -146.475500
# 5  ak0214xbmcgy        66 km ENE of Pedro Bay, Alaska  59.963600 -152.966800
#
#   locationSource          City                           County       State  \
# 0             ci        Seeley                  Imperial County  California
# 1             ak           Tok  Southeast Fairbanks Census Area      Alaska
# 2             hv        Pahala                    Hawaii County      Hawaii
# 3             ak   Prudhoe Bay              North Slope Borough      Alaska
# 5             ak  Anchor Point          Kenai Peninsula Borough      Alaska
#
#   Country
# 0      US
# 1      US
# 2      US
# 3      US
# 5      US

# %%
# Time Df
Time = pd.DataFrame(merge_df, columns = ['id', 'time', 'lastUpdDatetime'])
Time.head()
# Out:
#              id                time     lastUpdDatetime
# 0    ci39854328 2021-04-17 22:20:58 2021-04-17 22:24:26
# 1  ak0214xbpmk2 2021-04-17 22:18:45 2021-04-17 22:22:38
# 2    hv72430407 2021-04-17 22:13:32 2021-04-17 22:16:50
# 3  ak0214xbn842 2021-04-17 22:07:24 2021-04-17 22:20:58
# 5  ak0214xbmcgy 2021-04-17 22:03:14 2021-04-17 22:06:45

# %% [markdown]
# ## Database

# %%
# connect to Postgres
engine = create_engine(f"postgresql://postgres:{password}@localhost/Earthquakes_db")
conn = engine.connect()

# %% [markdown]
# ### earthquake

# %%
# Insert data into earthquake table
Earthquake.to_sql(name='earthquake', con=engine, if_exists='append', index=False)

# %%
# earthquake - Query the data in Postgres
earthquake_table = pd.read_sql("SELECT * FROM earthquake", conn)
earthquake_table.head(5)
# Out:
#              id        type       depth   mag magType  rootMeanSquare  \
# 0    ci39854328  earthquake    6.040000  1.24      ml            0.22
# 1  ak0214xbpmk2  earthquake    3.000000  1.50      ml            0.59
# 2    hv72430407  earthquake   34.349998  1.85      md            0.12
# 3  ak0214xbn842  earthquake    1.200000  3.00      ml            0.78
# 4  ak0214xbmcgy  earthquake  124.800000  1.30      ml            0.43
#
#       status
# 0  automatic
# 1  automatic
# 2  automatic
# 3  automatic
# 4  automatic

# %% [markdown]
# ### location

# %%
# Insert data into location table
Location.to_sql(name='location', con=engine, if_exists='append', index=False)

# %%
# location - Query the data in Postgres
location_table = pd.read_sql("SELECT * FROM location", conn)
location_table.head(5)
# Out:
#              id                                 place   latitude   longitude  \
# 0    ci39854328                15km E of Ocotillo, CA  32.751000 -115.829333
# 1  ak0214xbpmk2          119 km NW of Yakutat, Alaska  60.299400 -141.245600
# 2    hv72430407            9 km ESE of Pāhala, Hawaii  19.182333 -155.393997
# 3  ak0214xbn842  111 km NNW of Arctic Village, Alaska  69.062500 -146.475500
# 4  ak0214xbmcgy        66 km ENE of Pedro Bay, Alaska  59.963600 -152.966800
#
#   locationSource          City                           County       State  \
# 0             ci        Seeley                  Imperial County  California
# 1             ak           Tok  Southeast Fairbanks Census Area      Alaska
# 2             hv        Pahala                    Hawaii County      Hawaii
# 3             ak   Prudhoe Bay              North Slope Borough      Alaska
# 4             ak  Anchor Point          Kenai Peninsula Borough      Alaska
#
#   Country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %% [markdown]
# ### time

# %%
# Insert data into time table
Time.to_sql(name='time', con=engine, if_exists='append', index=False)

# %%
# time - Query the data in Postgres
time_table = pd.read_sql("SELECT * FROM time", conn)
time_table.head(5)
# Out:
#              id                time     lastUpdDatetime
# 0    ci39854328 2021-04-17 22:20:58 2021-04-17 22:24:26
# 1  ak0214xbpmk2 2021-04-17 22:18:45 2021-04-17 22:22:38
# 2    hv72430407 2021-04-17 22:13:32 2021-04-17 22:16:50
# 3  ak0214xbn842 2021-04-17 22:07:24 2021-04-17 22:20:58
# 4  ak0214xbmcgy 2021-04-17 22:03:14 2021-04-17 22:06:45
